# %%
# LifeCycle for ML Projects
# 
#                                            {On AWS, Azure etc}   {Built on FLask}   {In Serialized Form}
#                                              |-------------|      |------------|       |------------|
#                                              | Deployment  | <--- |  Wep App   | <---> | ML Models  |    
#                                              |-------------|      |------------|       |------------|        
#                                                                          |
#   |------------|      |---------------|      |-------------|      |------|-----|      
#   |   Data     |      |  Exploratory  |      |   Feature   |      |   Model    |      
#   | Collection | ---> | Data Analysis | ---> | Engineering | ---> |  Training  | 
#   |------------|      |---------------|      |-------------|      |------------|
#                                                      \                /
#                                                       \              /
#                                                    |--------------------|
#                                                    | Feature Selection  |
#                                                    |--------------------|
