# %%
# Create a Github repository (Remote)

# Repository Preparation Steps :-
# 
#   - create a folder .ebextensions
#       - create a file "python.config"
#               - inside the config file write :-
#               - option_settings:
#                   "aws:elasticbeanstalk:container:python":
#                   WSGIPath: application: application
# 
#       - deploy the app on AWS using elasticbeanstalk
# 
#       - create code pipeline
