# %%
# We have a Initial Dataset
# We do all the preprocessing and get the Standardized and Cleaned Dataset

# This dataset is split into two parts :-
#       1. Training Dataset (70% of Dataset)
#               :- Dataset on which the Model will actually train

#       2. Test Dataset (30% of Dataset)
#               :- Dataset used in performance analysis of Model Trained

# Training Dataset is further split into two parts :-
#       1. Training Data 
#               :- Used for Training the Model
#       2. Validation Data 
#               :- Used for Hyperparameter tuning of Model

# %%
# Underfitting and Overfitting

# Model Type    |  Training Data  |	  Test Data   |	  Bias	  |  Variance
# --------------|-----------------|---------------|-----------|---------------
# Ideal 	    |  Good Accuracy  |	Good Accuracy |	Low Bias  | Low Variance
# Overfitting   |  Good Accuracy  |	Bad Accuracy  |	Low Bias  | High Variance
# Underfitting  |  Bad Accuracy   |	Bad Accuracy  |	High Bias |	High Variance


# When performance is good on Training Data, Model is said to have "Low Bias" and vice versa
# When Performance is good on Test Data, Model is said to have "Low Variance" and vice versa
