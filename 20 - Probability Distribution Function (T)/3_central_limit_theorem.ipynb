# %%
# Central Limit Theorem

# From a poulation, the means of sampled data always follows normal distribution.
# Regardless of whether the population follows gausian / non-gausian distribution.
# If Sampled data is large enough (n >= 30)

# In Simple Words :-

# If A Population follows Gausian/Non-Gausian Distribution
# Lets say We sampled 40 datapoints from the population and computed the mean 10 times
#       lets say we get the means : (x1, x2, x3, .. x10)
# Then (x1, x2, x3, .. x10) will follow normal distribution
