# %%
# Placeholders for Jinja2 Templates :-
# 1. {{ variable }}                 -   Substitute the variable with the value provided in render template function
# 2. {% logic %} ... {% endlogic %} -   for writing logic and looping statements like if, else, for etc
# 3. {# comments #}                 -   for writing comments

# 4. extends & block                -   keyword used in template inheritance
# 5. include                        -   keyword used for reusing templates
