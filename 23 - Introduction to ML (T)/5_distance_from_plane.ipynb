# %%
from IPython.display import Image, display
display(Image(filename = "./assets/distance.png"))

# %%
# We know the vector W is perpendicular to Hyperplane.
# We also know the distance is measured along the perpendicular vector of the plane

# Unit Perpendicular vector along W :- w = W/|W|
# 
# Hence, Component of S along w = [ Perpendicular Distance (d)  = S.w = WᵀS/|W| ]

# Shortcut to remember :- 
# Replace all the values of variables in the equation with Point S
# Then divide by magnitude of coeff vector

# Practical Use :- 
# The points above the plane will give d > 0
# The points below the plane will give d < 0
# This concept is used in Support vector Machine

# We find the best boundary(hyperplane) which divides the set of points into seperate groups
# We maximize ∑(dᵢ) for each datapoint to find the best possible hyperplane
