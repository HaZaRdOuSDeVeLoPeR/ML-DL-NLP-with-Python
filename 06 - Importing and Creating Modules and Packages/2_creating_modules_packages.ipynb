# %%
# to make a package, make a folder with package name
# inside the package folder make a file "__init__.py"

# __init__.py is a special file which is used to define the packages 
# and initialize their namespaces
# from . import <module_names_inside_package>

# now inside the package folder, create the modules with module_name.py
# inside modules, define the required classes and functions

# Syntax for importing :- import mypackage.module_name.function_name
from calculator import *

print(real.adder.add(1,2,3))
print(real.subtractor.subtract(7,2,3))
print(real.multiplier.multiply(3,4,5))
print(real.divider.divide(40,5,5))

print(imaginary.adder.add((1,2),(3,4)))
print(imaginary.subtractor.subtract((4,5),(3,9)))
# Out:
# 6
# 2
# 60
# 1.6
# 4 + 6i
# 1 + -4i
