# %%
# Type I Error :- When Hypothesis was true but we rejected it
# Type II Error :- When Hypothesis was false but we accepted it

# Reaility    | Null Hypothesis is True       |   Null Hypothesis is False
# Decision    | Null Hypothesis is Rejected   |   Null Hypothesis is Accepted
# Error Type  |         Type I Error          |          Type II Error

# This concept is used in constructing confusion matrix for ML Models

# %%
# Confidence interval lies in the range :-

# Lower Confidence level    :-  x_low = μ - (z-score*σ)/sqrt(n)
# Higher Confidence level   :-  x_low = μ + (z-score*σ)/sqrt(n)
