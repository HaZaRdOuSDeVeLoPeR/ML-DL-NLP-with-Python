# %%
from IPython.display import Image, display
display(Image(filename = "./assets/z_test.png"))

# %%
# Z-Test

# Compulsory Conditions for Z-Test to be usable:-
# 1. Population mean (μ) and Standard Deivation (σ) should be known
# 2. Sample size should be greater than 30 (n >= 30)

# Type 1 :- One Sample Z-Test
#             - Test whether the sample mean matches to that of population mean
#             - Testing whether the sample is drawn from the population or not

# Type 2 :- Two Sample Z-Test
#             - Test whether the two independent samples are drawn from two different populations or same population

# Steps :-
# Step 1 :- Compute z-score for the sample(s)

# Step 2 :- Determine whether to do single tailed or double tailed test
#           - For =, !=             {Perform Double Tailed Test}
#           - For >=, <=, >, <      {Perform Single Tailed Test}

# Test Type	     Null Hypothesis (H₀)	    Alternative (Hₐ)
# Left-tailed	    μ ≥ μ₀ (has =)	            μ < μ₀
# Right-tailed	    μ ≤ μ₀ (has =)	            μ > μ₀
# Two-tailed	    μ = μ₀ (has =)	            μ ≠ μ₀

# Step 3 :- Compute z(alpha) from the given confidence level (LOS)
#           - Determine the confidence level area and boundaries

# Step 4 :- If z-score lies within the confidence region {region constituting z = 0}
#           - then accept H0 
#           - else reject


# Example
# A factory manufactures bulbs with average warranty of 5 yrs with std of 0.5 yrs. 
# A worker believes that the bulb will malfunction in less than 5 yrs. 
# He tests a sample of 40 bulbs and finds the average life to be 4.8 yrs.
# At 2% level of significance, is there enough evidence to support the idea that the warranty should be revised ?

# Here  H0 : μ >= 5 (must always consist of equality)
#       H1 : μ < 5  (left tailed test)                  
#                   {Consider negative value of Z-score from Z-Table}
