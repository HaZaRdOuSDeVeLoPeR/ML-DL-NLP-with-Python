# %%
from IPython.display import Image, display
display(Image(filename = "./assets/t_test1.png"))
display(Image(filename = "./assets/t_test2.png"))
display(Image(filename = "./assets/t_test3.png"))

# %%
# T-Test

# Conditions pointing towards t-test :- {if any one of the given condition is true}
# 1. If population standard deviation is not known and we have to use sample standard deviation
# 2. If sample size is small (n < 30)

# Type 1 :- One Sample t-Test
#             - Test whether the sample mean matches to that of population mean
#             - Testing whether the sample is drawn from the population or not

# Type 2 :- Two Sample t-Test
#             - Test whether the two independent samples are drawn from two different populations or same population

# Type 3 :- Paired t-Test
#             - Tests whether there is a significant affect on the original observations due to some external factors

# Steps :-
# Step 1 :- Compute t-score for the sample(s)

# Step 2 :- Determine whether to do single tailed or double tailed test
#           - For =, !=             {Perform Double Tailed Test}
#           - For >=, <=, >, <      {Perform Single Tailed Test}

# Test Type	     Null Hypothesis (H₀)	    Alternative (Hₐ)
# Left-tailed	    μ ≥ μ₀ (has =)	            μ < μ₀          {-ve z(alpha)}
# Right-tailed	    μ ≤ μ₀ (has =)	            μ > μ₀          {+ve z(alpha)}
# Two-tailed	    μ = μ₀ (has =)	            μ ≠ μ₀

# Step 3 :- Compute t(alpha, df) from the given confidence level (LOS) and degree of freedom (df)
#           - Determine the confidence level area and boundaries

# Step 4 :- If t-score lies within the confidence region {region constituting t = 0}
#           - then accept H0
#           - else reject
